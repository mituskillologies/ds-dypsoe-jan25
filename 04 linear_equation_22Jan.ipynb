# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(1, 10, 0.5)

# %%
x
# Out:
# array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. ,
#        7.5, 8. , 8.5, 9. , 9.5])

# %%
y = 1.2 * x + 15

# %%
y
# Out:
# array([16.2, 16.8, 17.4, 18. , 18.6, 19.2, 19.8, 20.4, 21. , 21.6, 22.2,
#        22.8, 23.4, 24. , 24.6, 25.2, 25.8, 26.4])

# %%
plt.plot(x, y);
